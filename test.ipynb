# %%
import netCDF4

path = "E:/final year project data/nigeria/2008/nigeria_ssrd_2008.nc"
ds = netCDF4.Dataset(path)
print(ds)
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     GRIB_centre: ecmf
#     GRIB_centreDescription: European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre: 0
#     Conventions: CF-1.7
#     institution: European Centre for Medium-Range Weather Forecasts
#     history: 2026-03-24T20:35 GRIB to CDM+CF via cfgrib-0.9.15.1/ecCodes-2.42.0 with {"source": "tmpij1p8x8o/data.grib", "filter_by_keys": {"stream": ["oper"], "stepType": ["accum"]}, "encode_cf": ["parameter", "time", "geography", "vertical"]}
#     dimensions(sizes): valid_time(8784), latitude(39), longitude(50)
#     variables(dimensions): int64 number(), int64 valid_time(valid_time), float64 latitude(latitude), float64 longitude(longitude), <class 'str'> expver(valid_time), float32 ssrd(valid_time, latitude, longitude)
#     groups:

# %%
import pandas as pd
data = pd.read_csv(r'c:\Users\chiom\Documents\Final Year Project\web app\data\processed\australia_processed_data.csv')
df = pd.DataFrame(data)
print(df)
# Out:
#                        time  solar_radiation    wind_u    wind_v  cloud_cover  \
# 0       2008-01-01 00:00:00     1.552709e+06  0.516971 -0.483560     0.448459
# 1       2008-01-01 01:00:00     2.095126e+06  0.518695 -0.457162     0.434007
# 2       2008-01-01 02:00:00     2.513184e+06  0.512710 -0.396469     0.438184
# 3       2008-01-01 03:00:00     2.762637e+06  0.501655 -0.323799     0.432534
# 4       2008-01-01 04:00:00     2.818965e+06  0.508238 -0.247781     0.444846
# ...                     ...              ...       ...       ...          ...
# 148891  2024-12-31 19:00:00     1.235820e+03  0.122263  0.133212     0.608772
# 148892  2024-12-31 20:00:00     2.841327e+04  0.095156  0.144440     0.607390
# 148893  2024-12-31 21:00:00     1.701923e+05  0.036042  0.143227     0.600735
# 148894  2024-12-31 22:00:00     5.175476e+05  0.121575  0.135050     0.621246
# 148895  2024-12-31 23:00:00     1.053868e+06 -0.012850  0.128720     0.594979
#
# ...

# %%
df.isnull().sum()
# Out:
# time                                        0
# solar_radiation                             0
# wind_u                                      0
# wind_v                                      0
# cloud_cover                             87672
# pressure                                78888
# precipitation                           70128
# temperature_celsius                     96432
# dewpoint_celsius                        61344
# wind_speed                                  0
# wind_direction                              0
# relative_humidity                       96432
# hour                                        0
# day_of_week                                 0
# day_of_year                                 0
# month                                       0
# is_weekend                                  0
# hour_sin                                    0
# hour_cos                                    0
# month_sin                                   0
# ...
